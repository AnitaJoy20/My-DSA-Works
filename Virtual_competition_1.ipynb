# %% [markdown]
# <a href="https://colab.research.google.com/github/AnitaJoy20/My-DSA-Works/blob/main/Virtual_competition_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df=pd.DataFrame(data, index=labels)
print('Data Frame is ')
df
# Out:
# Data Frame is
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
print("Summary of the basic information about this DataFrame and its data:")
df.info()
# Out:
# Summary of the basic information about this DataFrame and its data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
print("The first 3 rows of the DataFrame are ")
df.head(3)
# Out:
# The first 3 rows of the DataFrame are
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
print("Animal and Age coloumns in Data Frame : ")
dfa = df[['animal', 'age']]
dfa
# Out:
# Animal and Age coloumns in Data Frame :
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
print("Data in rows [3, 4, 8] and in columns `['animal', 'age']' : ")
dfa.iloc[[1, 3, 5, 6]]
# Out:
# Data in rows [3, 4, 8] and in columns `['animal', 'age']' :
#   animal  age
# b    cat  3.0
# d    dog  NaN
# f    cat  2.0
# g  snake  4.5

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
print("rows where the number of visits is greater than 3.")
df[df['visits'] > 3]
#No rows with visits greater than 3
# Out:
# rows where the number of visits is greater than 3.
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
print("rows where the age is missing.")
df[df['age'].isna()]
# Out:
# rows where the age is missing.
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
print("rows where the animal is a cat and the age is less than 3 :")
df[(df['animal'] == 'cat') & (df['age'] < 3) ]
# Out:
# rows where the animal is a cat and the age is less than 3 :
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
print("rows where the age is between 2 and 4 (inclusive)") 
(df[df['age'].between(2,4)])
# Out:
# rows where the age is between 2 and 4 (inclusive)
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
print("Updated age in row 'f' to 1.5.") 
df.at['f','age']='1.5'
df
# Out:
# Updated age in row 'f' to 1.5.
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
print("the total number of visits")
print(df['visits'].sum())
# Out:
# the total number of visits
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
 #df.mean()
 #df[["age"]].mean()
df.groupby('animal')['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1790             try:
# -> 1791                 result = self.grouper._cython_operation(
#    1792                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038         ngroups = self.ngroups
# -> 1039         return cy_op.cython_operation(
#    1040             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     707
# --> 708         return self._cython_op_ndim_compat(
#     709             values,
#
# ...

# %%
#df.groupby('animal')['age'].mean()
df[['age']].mean()
# Out:
# <ipython-input-69-da8a166bbee5>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[['age']].mean()
# Series([], dtype: float64)

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
new_row = {'animal':'rat', 'age':5, 'visits':92, 'priority':'yes'}
print("Adding new row k")
df.append(pd.DataFrame([new_row],index=['k'],columns=df.columns))
# Out:
# Adding new row k
# <ipython-input-76-ca92031360fa>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(pd.DataFrame([new_row],index=['k'],columns=df.columns))
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k    rat    5      92      yes

# %%
print("delete that row to return the original DataFrame.")
df.drop('k')
df
# Out:
# delete that row to return the original DataFrame.
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
print("delete that row to return the original DataFrame.")
df
# Out:
# delete that row to return the original DataFrame.
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
print("Count the number of each type of animal in df.")
df.pivot_table(index = ['animal'], aggfunc ='size')
# Out:
# Count the number of each type of animal in df.
# animal
# cat      4
# dog      4
# snake    2
# dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df.sort_values(["age","visits"], ascending=[False, True])
# Out:
#   animal  age  visits priority
# f    cat  1.5       3       no
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'] = df['priority'].map({'yes': True, 'no': False})
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      NaN
# b    cat  3.0       3      NaN
# c  snake  0.5       2      NaN
# d    dog  NaN       3      NaN
# e    dog  5.0       2      NaN
# f    cat  1.5       3      NaN
# g  snake  4.5       1      NaN
# h    cat  NaN       1      NaN
# i    dog  7.0       2      NaN
# j    dog  3.0       1      NaN

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      NaN
# b    cat  3.0       3      NaN
# c  snake  0.5       2      NaN
# d    dog  NaN       3      NaN
# e    dog  5.0       2      NaN
# f    cat  1.5       3      NaN
# g  snake  4.5       1      NaN
# h    cat  NaN       1      NaN
# i    dog  7.0       2      NaN
# j    dog  3.0       1      NaN

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
#df.replace('snake', 'python')
df.replace('snake', 'python')
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1       NaN
# b     cat  3.0       3       NaN
# c  python  0.5       2       NaN
# d     dog  NaN       3       NaN
# e     dog  5.0       2       NaN
# f     cat  1.5       3       NaN
# g  python  4.5       1       NaN
# h     cat  NaN       1       NaN
# i     dog  7.0       2       NaN
# j     dog  3.0       1       NaN

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
flights = pd.read_csv('ny-flights.csv')
flights
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
flights['airline_id'].mode()
# Out:
# 0    20409
# Name: airline_id, dtype: int64

# %%
flights['airline_id'].value_counts().idxmax()
# Out:
# 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
#flights.plot(x='dep_delay',y='arr_delay',title ="Delay vs arrival")

sns.scatterplot(x="dep_delay", y="arr_delay",data=flights)
# Out:
# <Axes: xlabel='dep_delay', ylabel='arr_delay'>
